# %% [markdown]
# # AI Trading Bot - V2 Feature Engineering and Training

# %% [markdown]
# ### Step 1: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 2: Clone the Repository and Install Dependencies

# %%
# %cd /content/drive/MyDrive
# !git clone --branch google-collab YOUR_GITHUB_REPOSITORY_URL_HERE trading-ai
# %cd trading-ai
# !pip install --force-reinstall -r requirements.txt

# %% [markdown]
# ### Step 3: Run the Feature Engineering Pipeline

# %%
# !python src/tier2/create_lean_dataset.py
# !python src/tier2/feature_engineering_v2.py

# %% [markdown]
# ### Step 4: Train the V2 Model

# %%
# !python src/tier2/train_lgbm_v2.py

# %% [markdown]
# ### Step 5: Run the V2 Backtest

# %%
# !python src/tier2/run_backtest_v2.py
