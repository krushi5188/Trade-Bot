# %% [markdown]
# # AI Trading Bot - V2 Feature Engineering and Training (Robust Version)

# %% [markdown]
# ### Step 1: Prevent Session Timeouts (Optional but Recommended)

# %%
from IPython.display import display, Javascript
import time

def prevent_timeout():
    display(Javascript('''
        function ClickConnect(){
            console.log("Keeping alive");
            document.querySelector("colab-toolbar-button#connect").click()
        }
        setInterval(ClickConnect, 60000)
    '''))

# Call this function to start the keep-alive script.
prevent_timeout()

# %% [markdown]
# ### Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 3: Clone Repository and Install Dependencies

# %%
# %cd /content/drive/MyDrive
# !git clone --branch google-collab YOUR_GITHUB_REPOSITORY_URL_HERE trading-ai
# %cd trading-ai
# !pip install --force-reinstall -r requirements.txt

# %% [markdown]
# ### Step 4: Run the Robust Feature Engineering Pipeline
# This script now includes periodic checkpointing. If it fails, you can resume from the last saved checkpoint.

# %%
# !python src/tier2/create_lean_dataset.py
# !python src/tier2/feature_engineering_v2.py

# %% [markdown]
# ### Step 5: Train the V2 Model (with GPU acceleration)

# %%
# !python src/tier2/train_lgbm_v2.py

# %% [markdown]
# ### Step 6: Run the V2 Backtest

# %%
# !python src/tier2/run_backtest_v2.py
