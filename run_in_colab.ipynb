# %% [markdown]
# # AI Trading Bot - V2 GPU-Accelerated Pipeline

# %% [markdown]
# ### Step 1: Prevent Session Timeouts & Mount Google Drive

# %%
from IPython.display import display, Javascript
def prevent_timeout():
    display(Javascript('''
        function ClickConnect(){
            console.log("Keeping alive");
            document.querySelector("colab-toolbar-button#connect").click()
        }
        setInterval(ClickConnect, 60000)
    '''))
prevent_timeout()

from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 2: Clone Repo & Install Standard Dependencies

# %%
# %cd /content/drive/MyDrive
# !git clone --branch google-collab YOUR_GITHUB_REPOSITORY_URL_HERE trading-ai
# %cd trading-ai
# !pip install --force-reinstall -r requirements.txt

# %% [markdown]
# ### Step 3: Install RAPIDS cuDF for GPU Acceleration
# This is a special installation for the GPU data science library.

# %%
# !pip install cudf-cu12 --extra-index-url=https://pypi.nvidia.com

# %% [markdown]
# ### Step 4: Run the GPU-Accelerated Feature Engineering Pipeline

# %%
# !python src/tier2/create_lean_dataset.py
# !python src/tier2/feature_engineering_v2_gpu.py

# %% [markdown]
# ### Step 5: Train the V2 Model (with GPU acceleration)

# %%
# !python src/tier2/train_lgbm_v2.py

# %% [markdown]
# ### Step 6: Run the V2 Backtest

# %%
# !python src/tier2/run_backtest_v2.py
